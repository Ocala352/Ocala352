# %% [markdown]
# <a href="https://colab.research.google.com/github/Ocala352/Ocala352/blob/main/PIG%20Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create the random number generator
import random

def roll():
  min_value = 1
  max_value = 6
  roll = random.randint(min_value, max_value)

  return roll

#Set up how many people can play the game

while True:
  players = input('Enter the numbers of players (2-4): ')
  if players.isdigit():
    players = int(players)
    if 2 <= players <= 4:
      break
    else:
      print('Must be between 2 - 4 players.')
  else:
      print('Invalid, try again')

max_score = 50
player_scores = [0 for _ in range(players)]

print(player_scores)

#Player terms for the game
while max(player_scores) < max_score:
  for player_idx in range(players):
    print('\nPlayer number', player_idx + 1, 'turn has just started!\n')
    print('Your total score is:' , player_scores[player_idx], '\n')
    current_score = 0

    while True:
      should_roll = input("Would you like to roll (y)?")
      if should_roll.lower() != 'y':
        break

      value = roll()
      if value == 1:
        print('You rolled a 1! Turn done!')
        current_score = 0
        break
      else:
        current_score += value
        print('You rolled a:', value)

      print('Your score is:', current_score)

    player_scores[player_idx] += current_score
    print('Your total score is:', player_scores[player_idx])

yy
#Let them know who has won the game
max_score = max(player_scores)
winning_idx = player_scores.index(max_score)
print('Player number', winning_idx + 1, 'is the winner with a score of:', max_score)
# Out:
# Enter the numbers of players (2-4): 2
# [0, 0]
#
# Player number 1 turn has just started!
#
# Your total score is: 0
#
# Would you like to roll (y)?y
# You rolled a: 3
# Your score is: 3
# Would you like to roll (y)?y
# You rolled a 1! Turn done!
# Your total score is: 0
#
# Player number 2 turn has just started!
#
# Your total score is: 0
#
# Would you like to roll (y)?y
# You rolled a: 5
# Your score is: 5
# Would you like to roll (y)?y
# You rolled a: 3
# Your score is: 8
# Would you like to roll (y)?y
# You rolled a: 5
# Your score is: 13
# Would you like to roll (y)?y
# You rolled a: 4
# Your score is: 17
# Would you like to roll (y)?
# Your total score is: 17
#
# Player number 1 turn has just started!
#
# Your total score is: 0
#
# Would you like to roll (y)?y
# You rolled a: 5
# Your score is: 5
# Would you like to roll (y)?y
# You rolled a: 5
# Your score is: 10
# Would you like to roll (y)?y
# You rolled a: 6
# Your score is: 16
# Would you like to roll (y)?y
# ...
